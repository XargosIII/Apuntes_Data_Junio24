# %% [markdown]
# # 6 - Peticiones a Webs y APIs
# ![api](https://images.ctfassets.net/vwq10xzbe6iz/5sBH4Agl614xM7exeLsTo7/9e84dce01735f155911e611c42c9793f/rest-api.png)

# %% [markdown]
# ##  6.1 - APIs
#
# En el mundo actual de la programación, las APIs (Interfaces de Programación de Aplicaciones, por sus siglas en inglés) desempeñan un papel fundamental al permitir la *comunicación y la integración entre diferentes programas* de software. Una API actúa como un conjunto de ***reglas y especificaciones*** que definen cómo dos aplicaciones pueden interactuar y compartir datos entre sí.
#
# Al utilizar una API, un desarrollador puede escribir un programa que solicite servicios o información de un sistema operativo, una plataforma en línea o cualquier otra aplicación que ofrezca una API pública (o de pago).
#
# La API proporciona una interfaz clara y definida a través de la cual el programa puede enviar solicitudes de procesamiento y recibir los datos necesarios en respuesta.
#
# Cada API tiene su propia sintaxis y estructura, que se describe en detalle en la documentación proporcionada por el proveedor de la API. Esta documentación explica cómo se deben formular las solicitudes, qué parámetros se deben incluir y cómo interpretar y utilizar las respuestas recibidas. Es importante tener en cuenta que cada API es única y puede tener diferentes métodos de autenticación, limitaciones de uso y características específicas.
#
# En general, las APIs constan de dos componentes principales. En primer lugar, está la especificación, que define cómo se realiza el intercambio de información entre programas. Esto incluye el formato de las solicitudes y respuestas, los tipos de datos admitidos y cualquier convención de nomenclatura necesaria. En segundo lugar, está la implementación real de la interfaz de software que cumple con la especificación. Esta implementación se proporciona y publica de alguna manera para que otros desarrolladores puedan utilizarla.
#
# En muchos casos, las APIs se utilizan para obtener información actualizada de fuentes externas. Esto puede incluir datos en tiempo real, como información meteorológica, cotizaciones de acciones, resultados de búsquedas o actualizaciones de redes sociales. Al acceder a estas APIs, los desarrolladores pueden enriquecer sus aplicaciones con datos relevantes y actualizados, brindando a los usuarios una experiencia más completa y personalizada.
#
# En resumen, las APIs son una herramienta poderosa para la comunicación y la integración de software. Permiten que diferentes programas se conecten y compartan datos de manera eficiente, al tiempo que brindan a los desarrolladores acceso a una amplia gama de servicios y recursos. Al comprender cómo interactuar con las APIs y aprovechar su funcionalidad, los desarrolladores pueden crear aplicaciones más sofisticadas y conectadas que se benefician de la vasta cantidad de información disponible en la web.
#
# De manera general, usaremos las api para obtener información.

# %% [markdown]
# ### Peticiones a la web (GET)
#
# Usaremos la librería [requests](https://docs.python-requests.org/en/master/) para realizar peticiones a la web.

# %%
#%pip install requests

# %%
import requests as req #Req es un standard en cuanto a alias para requests

# %%
url='http://www.google.es'

# %%
req.get(url)  # realiza la peticion get, nos da codigo 200, que es que todo ha ido bien

# %%
type(req.get(url))

# %%
respuesta = req.get(url) #Puedo guardarlo en una variable para trabajar con ello

# %% [markdown]
# Para ver el contenido de la respuesta que me da la web tengo que hacer a través del atributo `.text`

# %%
type(respuesta.text)

# %% [markdown]
# Esto es una string y es el html de la página, al ser una string podemos usar los métodos de las cadenas, recordáis? 🤔

# %%
respuesta.text#[:100] #Vamos a hacer un slicing del contenido de la web

# %% [markdown]
# ### Estructura general de un html
#
# Estructura general de un `html`
#
# ![html](https://francescricart.com/wp-content/uploads/2018/02/estructura-documento-web-1.jpg)
#
# Estructura general de `html5`
#
# ![html5](https://www.eniun.com/wp-content/uploads/estructura-etiquetas-html.png)

# %% [markdown]
# Esto es el contenido de la página de inicio de google que es lo que hemos usado como url. Vamos a cambiarlo, pero para ello vamos a ir un segundo a google para ver como compone las urls
#
# [Link a google](https://www.google.com/)

# %%
url='http://www.google.com/search?q=gamma+tech+school' #url con parametros, hay infinitos parametros

# %%
req.get(url)

# %%
#req.get(url).__dict__

# %% [markdown]
# Parece que todo ha ido bien verdad?
#
# Es muy común cuando estoy haciendo peticiones a la web en un .py o estoy haciendo peticiones en bucle, que necesite comprobar que las respuestas son correctas. ¿Como podemos hacerlo?

# %%
req.get(url)

# %%
#Podemos hacerlo así
req.get(url).status_code == 200

# %%
req.get(url).text[:1500] #Mostramos la primera parte de mi string

# %% [markdown]
# ### **F-strings** on steroids 💪 💪

# %% [markdown]
# Cuida la presentación de las ***salidas de tu código***. Se puede modificar el formato de cómo se va a mostrar el valor del código que está contenido entre las claves `{}`
#
# La manera de poder personalizar el formato es añadiendo dos puntos **`:`** y a continuación lo que sea que se necesite. Ejemplo:
# ```python
# print(f'{(codigo_aqui):<simbolo>} texto que continua.')
# ```
#
# * [docu oficial con ejemplos](https://docs.python.org/3/tutorial/inputoutput.html#formatted-string-literals)
# * [f-string al completo](https://docs.python.org/3/reference/lexical_analysis.html#f-strings)
# * [PEP701, sintaxis de la f-string](https://peps.python.org/pep-0701/#abstract)
# * [formateando la string... manual](https://docs.python.org/3/library/string.html#format-string-syntax)[texto del enlace](https://)

# %%
url = 'https://infocif.economia3.com/ranking/ventas-empresas/espana'
print(f'Tengo {len(req.get(url).text):_} caracteres') #El código puede ser enorme

# %%
variable = 2222222222
print(f'{variable=}')

# %%
print(f'variable = {variable}')

# %%
variable = 2.5465465465464645
print(f'{variable:.2f}')

# %%
print(f'{variable:.5f}')

# %%
req.get(url).text[:1000]

# %% [markdown]
# ## 6.2 - Llamadas a APIs 🤖

# %% [markdown]
# Existe un repo de GitHub con el listado más grande del mundo de APIs gratuitas listas para que las consultemos y usemos en nuestros proyectos
# 🌟 [repo](https://github.com/public-apis/public-apis) 🌟

# %% [markdown]
# ### Nobel Master Data (Api de [premios nobel](https://app.swaggerhub.com/apis/NobelMedia/NobelMasterData/2.1#/default/get_nobelPrizes) )

# %% [markdown]
# Vamos a hacerlo desde CERO. Lo primero vamos a ver la docu a ver que nos cuentan de como usarla

# %%
#Tenemos que conseguir esa url
url = 'http://api.nobelprize.org/2.1/nobelPrizes'

# %%
#Como podemos ver el contenido de manera más comoda y navegable?
response = req.get(url)
response

# %%
response.text

# %%
response.json() #Es el primo mayor de los diccionarios de Python

# %%
r = response.json() #response convertida en json
r.keys()

# %%
len(r['nobelPrizes'])

# %%
r['meta']

# %%
r['links']

# %% [markdown]
# Está limitado a 25, pero eso lo podemos modificar. Se cambia simplemente el endpoint. Fijaos que dice que hay datos de 670 premios Nobel. También, si analizáis el link, veis `offset=0&limit=25`
#
# Si modificamos simplemente que después de `nobelPrizes` esté el endpoint con otro limit podemos saltarnos esta limitación.

# %%
url = 'http://api.nobelprize.org/2.1/nobelPrizes?limit=1000'
#url = 'http://api.nobelprize.org/2.1/nobelPrizes'

# Sacando directamente el JSON accediendo directamente a la key 'nobelPrizes'
r = req.get(url).json()['nobelPrizes']
len(r)

# %%
r[0]

# %% [markdown]
# Podemos utilizar la API para ver directamente ciertos datos que nos interesen. Por ejemplo:
# * todos los premios (670)
# * ordenados de manera descendente
# * desde inicio de los registros (1901)
# * hasta año actual (2024)
# * de una categoría concreta (peace)

# %%
url_nueva = 'http://api.nobelprize.org/2.1/nobelPrizes?limit=670&sort=desc&nobelPrizeYear=1901&yearTo=2024'
r = req.get(url_nueva).json()['nobelPrizes']
len(r)

# %%
r

# %%
# Quiero que saquéis los datos necesarios para hacer un DataFrame con:
# año del premio
# nombre completo categoría
# nombre del premiado o de la organización

# %%
# Creamos un diccionario de listas que es lo que le gusta a pandas
dicc = {'año':[], 'categoría':[], 'premiado':[]}
import numpy as np


# Recorremos el Json de la response
for e in r:
  try:
    e['laureates']
    for premiado in e['laureates']:
      dicc['año'].append(e['awardYear']) #Cogemos el año
      dicc['categoría'].append(e['categoryFullName']['en']) #Cogemos la catergoría
      try:
        dicc['premiado'].append(premiado['fullName']['en'])
      except:
        #pass/ continue
        dicc['premiado'].append(premiado['orgName']['en'])
  except:
    dicc['año'].append(e['awardYear']) #Cogemos el año
    dicc['categoría'].append(e['categoryFullName']['en']) #Cogemos la catergoría
    dicc['premiado'].append('Sin premiado')

# %%
dicc.keys()

# %%
len(dicc['año'])

# %%
len(dicc['categoría'])

# %%
len(dicc['premiado'])

# %%
import pandas as pd
nobel_prizes = pd.DataFrame(dicc)
nobel_prizes

# %% [markdown]
# ### TRY / EXCEPT

# %%
lista = [ 23,'cadena', 0.0, {'soy una key':'soy un value'}]

# %%
for e in lista:
  resultado = e + 2

# %%
for e in lista:
  try:
    resultado = e + 2
    print(f"El resultado es {resultado}")
  except:
    print(f'No he podido hacerlo con: {e}')

# %%
for e in lista:
  try:
    resultado = e + 2
    print(f"El resultado es {resultado}")
  except: #continue / pass
    #continue --> sale de la iteracion actual sin ejecutar nada mas
    continue
    print(f'No he podido hacerlo con: {e}')

# %%
for e in lista:
  try:
    resultado = e + 2
    print(f"El resultado es {resultado}")
  except: #continue / pass
    #continue --> sale de la iteracion actual sin ejecutar nada mas
    continue
    print(f'No he podido hacerlo con: {e}')
  print('Esto lo hago porque estoy fuera del bucle')

# %%
for e in lista:
  try:
    resultado = e + 2
    print(f"El resultado es {resultado}")
  except: #continue / pass
    #pass  --> sigue con el codigo siguiente
    pass
    print(f'No he podido hacerlo con: {e}')

# %%
for e in lista:
  try:
    resultado = e + 2
    print(f"El resultado es {resultado}")
  except: #continue / pass
    #break  --> termina el bucle
    break
    print(f'No he podido hacerlo con: {e}')

# %%
for e in lista:
  try:
    resultado = e + 2
    print(f"El resultado es {resultado}")
  except Exception as e: #Capturo el error con Exception y lo muestro por pantalla
    print(e)

# %% [markdown]
# ### IMGFLIP (Api de [Memes](https://imgflip.com/api)):

# %%
import requests as req

# %%
url = 'https://api.imgflip.com/get_memes'#url de una api
response = req.get(url).json() # Para ver la respuesta en formato json
response

# %%
response['data']['memes'] #lista de los memes

# %%
#vamos a sacar el primer meme
response['data']['memes'][0]

# %%
#vamos a sacar la url de la imagen:
img_url = response['data']['memes'][40]['url']
img_url

# %%
#vamos a mostrar la imagen
from IPython.display import Image
Image('https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/Actinopyga_echinites1.jpg/250px-Actinopyga_echinites1.jpg')

# %%
len(response['data']['memes']) # para ver cuantos memes hay

# %%
#vamos a sacar las url de todos los memes
for meme in response['data']['memes'][20:30]:
    print(meme['url'])

# %%
id_meme = response['data']['memes'][40]['id']
id_meme

# %% [markdown]
# Vamos a crear nuestro primer MEME en Python
# cogemos como base el anterior 181913649
#
# Vamos a la docu de la API a ver que necesitamos

# %%
#Vamos a añadir un texto a este meme, vamos a la API y revisamos un poco a ver como funciona
url = 'https://api.imgflip.com/caption_image' #nueva url
template_id =  id_meme#'181913649' #id meme de Drake
texto_superior = 'Haciendo memes a mano'
texto_inferior = 'Haciendo memes con Python'
username = 'AlexBometon'
password = 'ImgFlip123456'

# %%
#Creamos un diccionario con nuestros parametros para la url
params = {'username':username,
          'password':password,
          'template_id': template_id,
          'text0':texto_superior,
          'text1':texto_inferior}

# %%
#Creamos ahora nuestro meme con el diccionario de parametros que hemos generado
req.get(url,params = params).json()['data']['url']

# %%
params = {'username':username,
          'password':password,
          'template_id': 181913649,
          'text0':texto_superior,
          'text1':texto_inferior}
req.get(url,params = params).json()['data']['url']

# %% [markdown]
# ### Evil Insults API

# %%
url = 'https://evilinsult.com/generate_insult.php?lang=es&type=json'
respuestas = []
for i in range(50):
  print(f'Voy con la llamada {i+1}')
  dicc = {}
  dicc['insulto'] = req.get(url).json()['insult']
  dicc['number'] =  req.get(url).json()['number']
  respuestas.append(dicc)

dicc

# %%
dicc

# %% [markdown]
# ### API de [Anime](https://jikan.moe/)

# %%
# Vamos a ver el perfil de usuarios aleatorios:

# %%
# ¿cómo saco su nombre de usuario?

# %%
#

# %% [markdown]
# Esta API me devuelve un único usuario. Pero quiero que me saque la información de por lo menos 3 usuarios diferentes. ¿Cómo podría hacerlo? Puedo hacerlo con un bucle for...
#
# Pero mejor hacerlo con un bucle while..

# %%
#Poder hacer esto en algun tipo de bucle

# %%
# vamos a ver los animes que tiene guardado cada usuario en favoritos:

# %%
# vamos a ver los animes que tiene guardado cada usuario en favoritos:

# %%
# vamos a ver únicamente los favoritos de un usuario

# %%
# qué tengo dentro del JSON
user.keys()

# %%
# qué tengo dentro de 'data'
user['data'].keys()

# %%
# tiene guardados en favs animes, mangas, personajes y personas.
# veamos los animes:
user['data']['anime']

# %%
# es una lista de diccionarios, para recorrer una lista tengo que ir por índice.
# qué títulos tiene guardados en favs
# la key es 'title'
# primero un bucle para recorrer la lista, cada elemento de la lista será un diccionario, así que quiero sacar los títulos
# al ser una lista necesito los índices empezando por 0
# ¿cómo miro la longitud?
len(user['data']['anime'])

# %%
# vamos a mirar los mangas que tiene en favs
len(user['data']['manga'])

# %%
user['data']['anime'][0].keys()

# %%
for i in range(len(user['data']['anime'])):
  # con user['data']['anime'] accedo a la lista
  # con user['data']['anime'][i] en cada iteración accederé a cada diccionario de esa lista
  # con user['data']['anime'][i]['title'] accederé a la key de cada diccionario
  print(user['data']['anime'][i]['title'])

# %%
foto = user['data']['anime'][0]['images']['jpg']['image_url']
foto

# %%
webp = user['data']['anime'][0]['images']['webp']['image_url'].split('?')[0]
from IPython.display import Image
Image(webp)#No nos admite formato webp

# %%
#Para mostras img en my notebook
from IPython.display import Image #Nos ayudamos de esta lib
Image(foto)

# %%
foto.split('?')[0]

# %%
Image(foto.split('?')[0])

# %%
# Busca tres usuarios (cuidado con el límite de peticiones)
# Busca sus series favoritas, deben tener series favoritas...
# Haz un DataFrame con dos columnas: usuario | animes
# Que cada usuario tenga el mismo índice, pero tantos registros como animes guardados en favoritos
# Haz un bucle y consigue imprimir:
  # Nombre de usuario
  # Todas las fotos de los animes favoritos (si hay foto, si no el título del anime)
  # Separador entre un usuario y otro

# %%
import requests as req

# %%
# Random user * 3
# url API para user random
url = 'https://api.jikan.moe/v4/random/users'

# Lista para guardar los 3 usuarios:
user_favs_list = []

# bucle de iteraciones infinitas hasta que consiga 3 usuarios
# solo añade usuarios si la lista de animes en favs contiene, al menos, un elemento
while len(user_favs_list) < 3:
  response = req.get(url).json()
  username = response['data']['username']
  url_favs = f'https://api.jikan.moe/v4/users/{username}/favorites'
  response = req.get(url_favs).json()
  if len(response['data']['anime']) > 0:
    user_favs_list.append((username, response))

for i in range(3):
  print(user_favs_list[i][0])

# %%
# Series favoritas
# url API para ver favs
url_favs = f'https://api.jikan.moe/v4/users/{username}/favorites'

# Lista para guardar los favoritos de cada usuario
# Estructura:
user_favs = []

for username in user_list:
  url_favs = f'https://api.jikan.moe/v4/users/{username}/favorites'
  favorites = req.get(url_favs).json()
  user_favs.append((username, favorites))

user_favs[0]

# %%
user_favs[0]

# %%
user_favs[1]

# %%
user_favs[2]

# %%
# user_favs[i][1] --> json
# user_favs[i][1]['data']['anime'][j]['title']--> título anime

# %%
user_favs

# %%
user = []
for tupla in user_favs_list:
  user.append(tupla[0])

# %%
favs = []
for tupla in user_favs_list:
  favs.append(tupla[1]['data']['anime'])

title_list = []
for dict_favs in favs:
  user_i_favs = []
  for favs in dict_favs:
    user_i_favs.append(favs['title'])
  title_list.append(user_i_favs)

len(title_list)

# %%
title_list

# %%
import pandas as pd

# %%
data = {'user':user, 'títulos':title_list}
df = pd.DataFrame(data)
df

# %%
df.explode('títulos')

# %%
# Ver fotos
from IPython.display import Image

for i in range(len(user_favs_list)):
  # Nombre usuario
  print('Nombre de usuario:')
  print(user_favs_list[i][0]+'\n')

  # Un user sin animes (en caso de no haber puesto condicional en el bucle while)
  if user_favs_list[i][1]['data']['anime'] == []:
      print('No tiene animes en favoritos')

  else:
    # fotos de los animes
    for j in range(len(user_favs_list[i][1]['data']['anime'])):
      display(Image(user_favs_list[i][1]['data']['anime'][j]['images']['jpg']['image_url'].split('?')[0]))

  print('*'*50)

# %% [markdown]
# ### [PokeAPI](https://pokeapi.co/)

# %%
import requests as req

# %%
url='https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0'
response = req.get(url).json()
len(response['results'])

# %%
url='https://pokeapi.co/api/v2/pokemon'
response = req.get(url).json()
response

# %%
len(response['results'])

# %%
# Reto de sacar los pokemon de agua:

# %%
# ¿qué tipos hay?
url = 'https://pokeapi.co/api/v2/type'
r_type = req.get(url).json()
r_type

# %%
#Sacar pokemos Normal / Volador (ambas clases a la vez)
#Solu JOVANNA, agrupamos nombres de Pokemon
pokemones_normales_voladores = []
tipos = []
pokemon_num = 1

#while pokemon_num <= 1302:
for i in range(1,1302):
  url = f"https://pokeapi.co/api/v2/pokemon/{i}"
  response = req.get(url)

# Filtramos solo las respuestas exitosas
  if response.status_code == 200:
    pokedatos = response.json()
    lista_tipos = pokedatos['types'] #lista de diccionarios con el tipo/s del pokemon
    nombre_pokemon = pokedatos['name']
    lista_tipos_del_pokemon = []
    for tipo in lista_tipos:
      lista_tipos_del_pokemon.append(tipo['type']['name'])
    #Comprobamos si en la lista de tipos del pokemon estan las clases que busco (flying, normal)
    if 'normal' in lista_tipos_del_pokemon and 'flying' in lista_tipos_del_pokemon:
      pokemones_normales_voladores.append(nombre_pokemon)
  else:
    response = req.get(url)
    #print(f'He fallado en el pokemon {i}:\n {response}')
print(f'Tengo {len(pokemones_normales_voladores)} pokemones normales y voladores a la vez')

# %%
# Solu YAN

nombres = [] # Con esto sacamos la lista de nombres de los pokemons
for pokemon  in req.get('https://pokeapi.co/api/v2/pokemon?limit=1500/').json()['results']:
  nombres.append(pokemon['name'])

# %%
pokemones_voladores_y_normales = []
for nombre in nombres:
  flag_normal = False
  flag_volador = False
  #Generamos la lista de tipos que tiene un pokemon:
  lista_tipos_de_mi_pokemon = [tipos['type']['name'] for tipos in req.get(f'https://pokeapi.co/api/v2/pokemon/{nombre}/').json()['types']]
  if 'normal' in lista_tipos_de_mi_pokemon and 'flying' in lista_tipos_de_mi_pokemon:
    pokemones_voladores_y_normales.append(nombre)
print(len(pokemones_voladores_y_normales))

# %%
pokemones_voladores_y_normales = []
for nombre in nombres:
  flag_normal = False
  flag_volador = False
  #Generamos la lista de tipos que tiene un pokemon:
  lista_tipos_de_mi_pokemon = [tipos['type']['name'] for tipos in req.get(f'https://pokeapi.co/api/v2/pokemon/{nombre}/').json()['types']]
  tipos_deseados = ['normal', 'flying']
  if set(tipos_deseados).issubset(lista_tipos_de_mi_pokemon):
    pokemones_voladores_y_normales.append(nombre)
pokemones_voladores_y_normales

# %%
tipos_deseados = set(['normal', 'flying'])
tipos_deseados

# %%
pokemon1 = ['flying','normal']
pokemon2b = ['normal', 'flying', 'error']
if set(pokemon2b) == set(['flying','normal']):
  print('True')
else: print('No cumple')

# %%
#SOLU Gino
url = 'https://pokeapi.co/api/v2/type'
req_type = req.get(url).json()

url_normal = req_type['results'][0]['url']
get_normal = req.get(url_normal).json()
get_normal

url_volador = req_type['results'][2]['url']
get_volador = req.get(url_volador).json()
get_volador

poke_normal = get_normal['pokemon']
normal_pokemons = [pokemon['pokemon']['name'] for pokemon in poke_normal]

poke_volador = get_volador['pokemon']
flying_pokemons = [pokemon['pokemon']['name']for pokemon in poke_volador]

#Tengo las dos listas
poke_normal_volador = [pokemon for pokemon in normal_pokemons if pokemon in flying_pokemons]
len(poke_normal_volador)

# %%
# accedo al link si el type es 'water' y hago el GET

for i in range(len(r_type['results'])):
  if r_type['results'][i]['name'] == 'water':
    url = r_type['results'][i]['url']
    print(url)

r_agua = req.get(url).json()
r_agua

# %%
r_agua.keys()

# %%
# es una lista
r_agua['pokemon']

# %%
r_agua['id']

# %%
# lista pokemon agua sacando directamente los pokemon de agua
poke_agua = []
for i in range(len(r_agua['pokemon'])):
  poke_agua.append(r_agua['pokemon'][i]['pokemon']['name'])
poke_agua

# %%
# sacar todo el json y conseguir los pokemon de agua desde ese json
url='https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0'
r = req.get(url).json()

# %%
r.keys()

# %%
r['results'][0]

# %%
# bucle para acceder a cada pokemon y ver su type
r2 = req.get(r['results'][0]['url']).json()
r2

# %%
r2.keys()

# %%
r2['types']

# %%
# sacar los pokemon de agua desde los datos completos

pokemon_agua = []
url = 'https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0'
r = req.get(url).json()
for pokemon in r['results']:
  name = pokemon['name']
  url = pokemon['url']
  r2 = req.get(url).json()
  for tipo in r2['types']:
    if tipo['type']['name'] == 'water':
      pokemon_agua.append(name)

# %%
# ¿cuántos hay?
len(pokemon_agua)

# %%
#Reto de sacar los Pokemons de Agua:
URL ='https://pokeapi.co/api/v2/type/11/' #11 = water = agua
# Es equivalente a la URL --> 'https://pokeapi.co/api/v2/type/water'
r = req.get(URL).json()
pokemons_agua = []
for e in r['pokemon']:
  pokemons_agua.append(e['pokemon']['name'])
len(pokemons_agua)

# %%
#Ida de olla de Ruben para sacar listado de pokemons en 1 0 2 clases y nos saca distinta info:
import requests as req
from IPython.display import Image

# Visualizador de pokemon de cualquier tipo

# Primero recogemos todos los tipos haciendo una llamada al endpoint type de la API
URL='https://pokeapi.co/api/v2/type'
respuesta = req.get(URL).json()

# Este bloque crea y muestra una lista de cadenas con los nombres de los tipos
print(f"¡Vamos a elegir pokemons por tipo!\n\nTipos disponibles:")
tipos_disp = []
linea = ""
# Usando enumerate en un iterable, nos da tanto el indice como los elementos
for indice, tipo in enumerate(respuesta['results']):
  linea = linea + tipo['name'] + ", "
  tipos_disp.append(tipo['name'])
  # Esto le da formato al print. Con las f strings con esteroides no he
  # encontrado la manera de separarlo y hacer el salto de linea a la vez.
  if (indice+1) % 4 == 0:
    print(linea, end="\n")
    linea = ""

# Guardamos la cantidad de tipos que el usuario quiere buscar
cant_tipos = 0
cant_tipos = input("\nElija cantidad de tipos a buscar(1 o 2): ")
while(cant_tipos not in ("1","2")):
  cant_tipos = input("Teclee solo 1 o 2: ")
cant_tipos = int(cant_tipos)

# Este bloque guarda el primer tipo y ademas, todos los nombres de los pokemon
# de ese tipo. Estos son devueltos como un diccionario usando el endpoint type con el parametro tip
tipos_eleg = []
tipos_eleg.append(input("Teclee un tipo: "))
while(tipos_eleg[0] not in tipos_disp):
  tipos_eleg[0] = input("Elija un tipo valido(ver lista arriba): ")
URL_1=f'https://pokeapi.co/api/v2/type/{tipos_eleg[0]}/'
tipo_uno = [pokemon['pokemon']['name'] for pokemon in req.get(URL_1).json()['pokemon']]

# Este bloque nos saca el resultado de pokemon que comparten tipo con el primer
# tipo. O si no cumple el if, convertimos el tipo_uno en el resultado
if cant_tipos == 2:
  tipos_eleg.append(input("Teclee segundo tipo: "))
  while(tipos_eleg[1] not in tipos_disp):
    tipos_eleg[1] = input("Elija un tipo valido(ver lista arriba): ")
  URL_1=f'https://pokeapi.co/api/v2/type/{tipos_eleg[1]}/'
  tipo_dos = [pokemon['pokemon']['name'] for pokemon in req.get(URL_1).json()['pokemon']]
  print(f"\nSeleccionado Pokemon que contengan dos tipos\nTipos elegidos: {'/'.join(tipos_eleg)}")
  poke_resultado = set(tipo_uno).intersection(set(tipo_dos))
else:
  print(f"\nSeleccionado Pokemon por un solo tipo\nTipo elegido: {'/'.join(tipos_eleg)}")
  poke_resultado = tipo_uno

# Pokefor, pokesi, pokeresultado
for pokemon in tipo_uno:
  if pokemon in poke_resultado:
    URL=f'https://pokeapi.co/api/v2/pokemon/{pokemon}'
    respuesta = req.get(URL).json()
    print(f'\nPokemon: {respuesta["name"]}\nNº Pokedex Nacional: {respuesta["id"]}\nAltura: {respuesta["height"]/10}m  Peso: {respuesta["weight"]/10}kg\n')
    display(Image(respuesta['sprites']['front_default']))

# Con funciones seria mas eficiente y chulo. Pero hubiera sido mucho mas
# dificil de explicar, creo yo.

# %% [markdown]
# ### [ISS](https://wheretheiss.at/w/developer) API

# %%
url = 'https://api.wheretheiss.at/v1/satellites'
res_iss = req.get(url)
res_iss

# %%
res_iss.json()

# %%
url = 'https://api.wheretheiss.at/v1/satellites/25544'
req.get(url)
# Out:
# <Response [200]>

# %%
res_iss = req.get(url).json() #Para ver la respuesta en formato json
res_iss

# %%
res_iss2 = req.get(url).json() #Para ver la respuesta en formato json
res_iss2

# %%
res_iss == res_iss2

# %% [markdown]
# La respuesta ha cambiado los datos, es decir nos está dando la posición actual de la ISS en cada momento en el que hacemos la petición.🤔🤔🤔💡

# %%
#Vamos a trackear a la ISS
import time
import requests as req
from IPython.display import clear_output
posiciones = []
for i in range(300):
  print(f'Llamada {i+1} de 150')
  res_iss = req.get(url)
  data = res_iss.json()
  posiciones.append(data)
  time.sleep(3) #Tiempo en segundos que mi codigo va a parar antes de continuar
  clear_output(wait = True)
# Out:
# Llamada 300 de 150

# %%
len(posiciones)
# Out:
# 300

# %%
posiciones[1]

# %%
#Demo de pseudo progreso, de esta manera podemos saber en que punto de ejecución anda nuestro código
from IPython.display import clear_output
import time
for i in range(1,50):
  #print(f'{i}/30')
  print(f'{(i*100)/50:.2f} %')
  #, end="\r") #BUG de Collab no funciona el borrado de la linea
  #FUncion super compleja y super larga

  clear_output(wait = True)
  time.sleep(0.7)

# %%
from datetime import datetime
from IPython.display import clear_output
import time
import random
lista_tiempos_ejecucion = []
lista = list(range(100))
for i, e in enumerate(lista, start= 1):
  iteraciones_restantes = len(lista) - i #Restantes = total - las que llevo
  start = datetime.now().strftime("%Y%m%d%H%M%S")
  print(f'{i*100/len(lista):.2f} %')

  #Codigo complejo que hace cosas
  tiempo_random = random.randint(1,6)
  time.sleep(tiempo_random)

  finish = datetime.now().strftime("%Y%m%d%H%M%S")

  tiempo_empleado = int(finish) - int(start)
  #Media de tiempos de ejecucion
  lista_tiempos_ejecucion.append(tiempo_empleado)

  media_tiempo_ejecucion = sum(lista_tiempos_ejecucion)/len(lista_tiempos_ejecucion)
  print(f'Quedan {iteraciones_restantes*media_tiempo_ejecucion:.2f} segundos (media {media_tiempo_ejecucion}:.2f)')
  time.sleep(3)
  clear_output(wait=True)

# %%
def tiempo_restante(i, start_time, total):
  #lapso_de_tiempo = (tiempo_recorrido_actual - tiempo_comienzo).en segundos
  elapsed_time = (datetime.now() - start_time).total_seconds()
  #media_tiempo_x_iteración = lapso_de_tiempo / num.iteración
  avg_time_per_iteration = elapsed_time / i
  #iteraciones_restantes = num.total_iteraciones - num.iteración
  remaining_iterations = total - i
  #tiempo_restante = iteraciones_restantes * media_tiempo_x_iteración
  estimated_remaining_time = remaining_iterations * avg_time_per_iteration
  #devuelve tiempo_restante_estimado
  return estimated_remaining_time

# %%
# Vamos (vais) a integrar esta funcion en nuestro código
from datetime import datetime
from IPython.display import clear_output
import time
import random

lista = list(range(100))
for i, e in enumerate(lista, start= 1):
  start = datetime.now()

  #Codigo complejo que hace cosas guays
  tiempo_random = random.randint(1,6)
  time.sleep(tiempo_random)

  tiempo_empleado = tiempo_restante(i, start, len(lista))
  print(f'Tiempo estimado:{tiempo_empleado:.2f} segs')
  time.sleep(2)
  clear_output(wait=True)

# %%
posiciones[:2]

# %%
posiciones[0].keys()

# %%
import pandas as pd
df = pd.DataFrame(posiciones)
df.head()

# %%
df.shape

# %% [markdown]
# #### Vamos a ver como podemos representar estos datos
# vamos a echarle un ojo a la guia rápida de Folium:
#
# https://python-visualization.github.io/folium/quickstart.html#Getting-Started

# %%
#%pip install folium
import folium #Mapas en Python

# %%
m = folium.Map(location=(62.1234, -122.6750), tiles="cartodb positron")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a603524631e786a4346819721888bc34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a603524631e786a4346819721888bc34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a603524631e786a4346819721888bc34 = L.map(
#                 &quot;map_a603524631e786a4346819721888bc34&quot;,
#                 {
#                     center: [62.1234, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55ab72112d14dba776dfa8f988d9981a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_55ab72112d14dba776dfa8f988d9981a.addTo(map_a603524631e786a4346819721888bc34);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Añadimos un marcador
m = folium.Map(location=(62.1234, -122.6750), tiles="cartodb positron", zoom_start=5)
folium.Marker(
    location=[62.1234, -122.6750],
    tooltip="Usted está aquí!",
    popup="Donde cae esto?",
    icon=folium.Icon(color="blue"),
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d143f2b2e93a69b41663f0fa15d423d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d143f2b2e93a69b41663f0fa15d423d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d143f2b2e93a69b41663f0fa15d423d = L.map(
#                 &quot;map_0d143f2b2e93a69b41663f0fa15d423d&quot;,
#                 {
#                     center: [62.1234, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89705ad1679c48c973994133d206d379 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_89705ad1679c48c973994133d206d379.addTo(map_0d143f2b2e93a69b41663f0fa15d423d);
#
#
#             var marker_5c96d6ceb0e900c818b7f15100e02d3a = L.marker(
#                 [62.1234, -122.675],
#                 {}
#             ).addTo(map_0d143f2b2e93a69b41663f0fa15d423d);
#
#
#             var icon_0d78a668ed618943e5c0aa2f261b0293 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5c96d6ceb0e900c818b7f15100e02d3a.setIcon(icon_0d78a668ed618943e5c0aa2f261b0293);
#
#
#         var popup_d022e1517bd9bbc9372ae947b4872ceb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11856081e4af2171c48e0c712cd1860f = $(`&lt;div id=&quot;html_11856081e4af2171c48e0c712cd1860f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donde cae esto?&lt;/div&gt;`)[0];
#                 popup_d022e1517bd9bbc9372ae947b4872ceb.setContent(html_11856081e4af2171c48e0c712cd1860f);
#
#
#
#         marker_5c96d6ceb0e900c818b7f15100e02d3a.bindPopup(popup_d022e1517bd9bbc9372ae947b4872ceb)
#         ;
#
#
#
#
#             marker_5c96d6ceb0e900c818b7f15100e02d3a.bindTooltip(
#                 `&lt;div&gt;
#                      Usted está aquí!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = df[['latitude', 'longitude', 'timestamp']]
df

# %%
punto_inicio = df.iloc[0,0:2].values
punto_inicio

# %%
iss = folium.Map(location=punto_inicio, tiles="cartodb positron", zoom_start=2)
folium.Marker(
    location=punto_inicio,
    tooltip="Primera llamada",
    popup=f"{punto_inicio}",
    icon=folium.Icon(color="blue"),
).add_to(iss)
iss

# %%
iss = folium.Map(location=punto_inicio, tiles="cartodb positron", zoom_start=6)
#Creando marcadores en bucle
for i,row in df.iterrows():
  coordenada = (row['latitude'], row['longitude'])

  folium.Marker(
      location = coordenada,
      tooltip="",
      popup=f"{coordenada}",
      icon=folium.Icon(color="blue"),
  ).add_to(iss)
iss

# %%
df.head()

# %%
df['hora'] = pd.to_datetime(df['timestamp'], unit='s')
df

# %%
df2 = df.copy()

# %%
#Para transformar la hora en algo legible por humnaos
df['hora'] = pd.to_datetime(df['timestamp'], unit='s') #Le decimos que este entero representa segundos desde el 1 de enero de 1970

# %% [markdown]
# <p align='center'>
# <img src = 'https://media.tenor.com/w-PCA2wkMQEAAAAC/mind-blown-shocked.gif' />
# </p>

# %% [markdown]
# DOCU completa de [Folium](https://python-visualization.github.io/folium/)

# %%
import requests as req
url = 'https://cartes.io/api/maps'
header = {'Accept': 'application/json'}
response = req.get(url, headers=header)
response

# %%
r = response.json()
r.keys()

# %%
r['data'][3]

# %% [markdown]
# ### [Nasa](https://api.nasa.gov/) API

# %% [markdown]
# Esta API nos va a mostrar fotos tomadas en marte por el **curiosity**.
#
# [Listado](https://api.nasa.gov/) completo de las APIs que la NASA nos ofrece. Unas necesitan API_KEY y otras no.

# %%
#Vamos a recuperar 3 fotos del MAST y una foto de la camara QUIMICA (CHEMCAM)

# %%
#Solu YAN
lista_fotos_mast = []
lista_fotos_chem = []
for i, foto in enumerate(fotos['photos'], start= 1):
  print(i,foto['camera']['name'])
  if foto['camera']['name'] == 'MAST' and len(lista_fotos_mast) < 3:
    lista_fotos_mast.append(foto['img_src'])
  elif foto['camera']['name'] == 'CHEMCAM' and len(lista_fotos_chem) < 3:
    lista_fotos_chem.append(foto['img_src'])
  if len(lista_fotos_mast) == 3 and len(lista_fotos_chem) == 3:
    break

# %%
#Vamos a descargar las fotos a nuestro ordenador
img_data = req.get(lista_fotos_mast[0]).content
with open('image_name.jpg', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# #### Tenemos también un endpoint que nos da la foto del día

# %%
imagen_del_dia = 'https://api.nasa.gov/planetary/apod?api_key=DEMO_KEY'

req.get(imagen_del_dia).json()

# %%
#Mostremos la imagen del dia

# %%
#POdemos acceder a la imagen del día para un día concreto

# %% [markdown]
# Hay APIs en las que necesitamos un usuario y clave para poder acceder a cierta información. En este caso, la API de Spotify, nos pide que nos registremos como desarrolladores y que creemos una cuenta y una APIKEY para poder acceder a la información....Eso para los que tengan tiempo y ganas.
#
# Por necesidades didácticas sólamente necesitamos unos datos para poder acceder....no hemos visto GIT aún pero todo queda reflejado, no pongáis códigos, claves o usuarios hardcodeados...pues a diario hay muchos usuarios que cometen este error y dejan sus claves al descubierto....y si quisiéramos ser malos podríamos coger una o varias claves.
#
# - Cagadinha https://github.com/maybemarhs/spotify_playlist/commit/bc900c1d9e3bb4906f1b5d9b4b2394ca9a1b57e5

# %% [markdown]
# # SPOTIFY

# %%
#%pip install spotipy

# %%
# SPOTIFY
#Datos del ususario:
CLIENT_ID = '0fa761327b7a4787a964cea122c160f4'
CLIENT_SECRET = '4e6cf52288654385a4a28ff3769d5e65'

# %%
#Nos autenticamos en la API de Spotify
#%pip install spotipy
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

# %%
#Vamos a ver que cosas podemos hacer con la API de Spotify
#Vamos a ver nuestras playlists
playlists = sp.user_playlists('SaraHenares')
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/sarahenares/playlists?offset=0&limit=50',
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 17,
#  'items': [{'collaborative': False,
#    'description': 'Café caliente, sillón blandito y la mejor lectura o compañía.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWZkMGGysxknj'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZkMGGysxknj',
#    'id': '37i9dQZF1DWZkMGGysxknj',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000002f2bd9075b7ae60e86459e19f',
#      'width': None}],
#    'name': 'Café, Libros.',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': '#ffffff',
#    'public': True,
#    'snapshot_id': 'ZszGaQAAAAB1Qu9yrqCK3B/is0bbkFvv',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWZkMGGysxknj/tracks',
#     'total': 150},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWZkMGGysxknj'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3b6veymPVivhTif8NQThae'},
#    'href': 'https://api.spotify.com/v1/playlists/3b6veymPVivhTif8NQThae',
#    'id': '3b6veymPVivhTif8NQThae',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e0228a80684d079ab9f8d0c2f3eab67616d00001e024277da4c011dcc87f012bbabab67616d00001e02ac89ab9bfbeaebb9ded4cebaab67616d00001e02ff13ea6975bf87a481b800bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e0228a80684d079ab9f8d0c2f3eab67616d00001e024277da4c011dcc87f012bbabab67616d00001e02ac89ab9bfbeaebb9ded4cebaab67616d00001e02ff13ea6975bf87a481b800bf',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e0228a80684d079ab9f8d0c2f3eab67616d00001e024277da4c011dcc87f012bbabab67616d00001e02ac89ab9bfbeaebb9ded4cebaab67616d00001e02ff13ea6975bf87a481b800bf',
#      'width': 60}],
#    'name': 'Latinas',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAH8JN7A2MqERx4mGgxJl0GEmLOVHA',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3b6veymPVivhTif8NQThae/tracks',
#     'total': 29},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3b6veymPVivhTif8NQThae'},
#   {'collaborative': False,
#    'description': 'Música ambiental para un sueño profundo.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX7aAuYd7Jogj'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7aAuYd7Jogj',
#    'id': '37i9dQZF1DX7aAuYd7Jogj',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000002855a382003b3628024abfab2',
#      'width': None}],
#    'name': 'Sueño Profundo',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': '#ffffff',
#    'public': True,
#    'snapshot_id': 'ZtFDwAAAAAAC74wZa8m07/4/zvwc7TIu',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7aAuYd7Jogj/tracks',
#     'total': 191},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX7aAuYd7Jogj'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6wnntYTHtybYXHBaMBrLye'},
#    'href': 'https://api.spotify.com/v1/playlists/6wnntYTHtybYXHBaMBrLye',
#    'id': '6wnntYTHtybYXHBaMBrLye',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e0215c9243019c64cf7ef51ad1cab67616d00001e022df0d98a423025032d0db1f7ab67616d00001e0262591e84024cfa5b5269e830ab67616d00001e02be4309b37aa9a9ce570395c8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e0215c9243019c64cf7ef51ad1cab67616d00001e022df0d98a423025032d0db1f7ab67616d00001e0262591e84024cfa5b5269e830ab67616d00001e02be4309b37aa9a9ce570395c8',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e0215c9243019c64cf7ef51ad1cab67616d00001e022df0d98a423025032d0db1f7ab67616d00001e0262591e84024cfa5b5269e830ab67616d00001e02be4309b37aa9a9ce570395c8',
#      'width': 60}],
#    'name': 'Hits One Satellite Radio',
#    'owner': {'display_name': 'adizo',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/adizo'},
#     'href': 'https://api.spotify.com/v1/users/adizo',
#     'id': 'adizo',
#     'type': 'user',
#     'uri': 'spotify:user:adizo'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAESwgvjKu+Io+CG5BaSH5SMEGOqvZ1',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6wnntYTHtybYXHBaMBrLye/tracks',
#     'total': 55},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6wnntYTHtybYXHBaMBrLye'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3mxI4D9z5IpwJTn6gEnLZa'},
#    'href': 'https://api.spotify.com/v1/playlists/3mxI4D9z5IpwJTn6gEnLZa',
#    'id': '3mxI4D9z5IpwJTn6gEnLZa',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e0220cfa89d6a8c54f1c1371a71ab67616d00001e02715776e18d2ab95a5ba06c62ab67616d00001e02b23ded2daf5be916f9759077ab67616d00001e02bc160fb50f95b24424999bac',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e0220cfa89d6a8c54f1c1371a71ab67616d00001e02715776e18d2ab95a5ba06c62ab67616d00001e02b23ded2daf5be916f9759077ab67616d00001e02bc160fb50f95b24424999bac',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e0220cfa89d6a8c54f1c1371a71ab67616d00001e02715776e18d2ab95a5ba06c62ab67616d00001e02b23ded2daf5be916f9759077ab67616d00001e02bc160fb50f95b24424999bac',
#      'width': 60}],
#    'name': 'old music',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAALvD1g12nAKWC5UFEJ5Uol8lYQGuQ',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3mxI4D9z5IpwJTn6gEnLZa/tracks',
#     'total': 44},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3mxI4D9z5IpwJTn6gEnLZa'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3bSIfIx334DOM5s3STkCtr'},
#    'href': 'https://api.spotify.com/v1/playlists/3bSIfIx334DOM5s3STkCtr',
#    'id': '3bSIfIx334DOM5s3STkCtr',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0295517befb15ad5d63af701ab',
#      'width': None}],
#    'name': 'Michael Bublé – Christmas',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAAnh3E1U12BegF638/J+blMc+XFPj',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3bSIfIx334DOM5s3STkCtr/tracks',
#     'total': 16},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3bSIfIx334DOM5s3STkCtr'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7a1PNjIu3HlZN20yF33iXz'},
#    'href': 'https://api.spotify.com/v1/playlists/7a1PNjIu3HlZN20yF33iXz',
#    'id': '7a1PNjIu3HlZN20yF33iXz',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02812bf6e212cb6077ab51c09d',
#      'width': None}],
#    'name': 'Canta Y Rie – Canta Y Rie en Navidad',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAAqMlFcYofv+FHsKYxDZG29r+701m',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7a1PNjIu3HlZN20yF33iXz/tracks',
#     'total': 12},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7a1PNjIu3HlZN20yF33iXz'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/18TVeWVEvpLfFZHbPhoPka'},
#    'href': 'https://api.spotify.com/v1/playlists/18TVeWVEvpLfFZHbPhoPka',
#    'id': '18TVeWVEvpLfFZHbPhoPka',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02264713afeb28fb8b33586e51',
#      'width': None}],
#    'name': 'Various Artists – Lo Mejor de la Música Cristiana',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAAiOnaz5/3vtNlmPdIAmjUNvqCJJT',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/18TVeWVEvpLfFZHbPhoPka/tracks',
#     'total': 33},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:18TVeWVEvpLfFZHbPhoPka'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4daPucVBCF6TXqkyhlw11u'},
#    'href': 'https://api.spotify.com/v1/playlists/4daPucVBCF6TXqkyhlw11u',
#    'id': '4daPucVBCF6TXqkyhlw11u',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020bce19c1923f9760715e4ba5',
#      'width': None}],
#    'name': 'Various Artists – Lo Mejor de la Música Cristiana, Vol. 2',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAArSYDUpL7OoRI+2ElhV+avFSTWAf',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4daPucVBCF6TXqkyhlw11u/tracks',
#     'total': 19},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4daPucVBCF6TXqkyhlw11u'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/342hSTVA7pL3XrHL1k9Xgd'},
#    'href': 'https://api.spotify.com/v1/playlists/342hSTVA7pL3XrHL1k9Xgd',
#    'id': '342hSTVA7pL3XrHL1k9Xgd',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e02264713afeb28fb8b33586e51ab67616d00001e0229daa8b8bc34ad0feb49240bab67616d00001e02ca051d1e4921fbc2add7b2beab67616d00001e02cfd7d16d3e235ed4f09dd929',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e02264713afeb28fb8b33586e51ab67616d00001e0229daa8b8bc34ad0feb49240bab67616d00001e02ca051d1e4921fbc2add7b2beab67616d00001e02cfd7d16d3e235ed4f09dd929',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e02264713afeb28fb8b33586e51ab67616d00001e0229daa8b8bc34ad0feb49240bab67616d00001e02ca051d1e4921fbc2add7b2beab67616d00001e02cfd7d16d3e235ed4f09dd929',
#      'width': 60}],
#    'name': 'Cristiana',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAMM0evvILfyLt8YJHuu8MJ+ljD0as',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/342hSTVA7pL3XrHL1k9Xgd/tracks',
#     'total': 49},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:342hSTVA7pL3XrHL1k9Xgd'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0NNyNoxSf7m8oSOgE56m2J'},
#    'href': 'https://api.spotify.com/v1/playlists/0NNyNoxSf7m8oSOgE56m2J',
#    'id': '0NNyNoxSf7m8oSOgE56m2J',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d29a5d713277b0b3d517507b',
#      'width': None}],
#    'name': 'Various Artists – The Hunger Games: Songs From District 12 And Beyond',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAABX2P56kz0k6zxtdd6V4ku4AWNHn9',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0NNyNoxSf7m8oSOgE56m2J/tracks',
#     'total': 16},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0NNyNoxSf7m8oSOgE56m2J'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1uMQgiQTSgtuYljwJjTAhX'},
#    'href': 'https://api.spotify.com/v1/playlists/1uMQgiQTSgtuYljwJjTAhX',
#    'id': '1uMQgiQTSgtuYljwJjTAhX',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024a0d98c2365aee8d01f1411e',
#      'width': None}],
#    'name': 'Various Artists – Christmas Hits',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAABGPRjGuxNFa6O+C7iegKkSEQxw+I',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1uMQgiQTSgtuYljwJjTAhX/tracks',
#     'total': 51},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1uMQgiQTSgtuYljwJjTAhX'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0rk601PlVtHCTjRmwqAEPY'},
#    'href': 'https://api.spotify.com/v1/playlists/0rk601PlVtHCTjRmwqAEPY',
#    'id': '0rk601PlVtHCTjRmwqAEPY',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02221ecb389e81e5acc0539c16',
#      'width': None}],
#    'name': 'Exam Study Classical Music Orchestra – Exam Study Classical Music to Increase Brain Power, Classical Study Music for Relaxation, Concentration and Focus on Learning - Classical Music and Classical ...',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAA5Dt7vZOD6jYv7PNqcWcmvTvN9N6',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0rk601PlVtHCTjRmwqAEPY/tracks',
#     'total': 70},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0rk601PlVtHCTjRmwqAEPY'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3UOgmWYfIOXZa2iSTa2quP'},
#    'href': 'https://api.spotify.com/v1/playlists/3UOgmWYfIOXZa2iSTa2quP',
#    'id': '3UOgmWYfIOXZa2iSTa2quP',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a3a89e94605d140ed6826b3e',
#      'width': None}],
#    'name': 'The Royal Vivaldi Symphony – Maestros de la musica clasica - Antonio Vivaldi. Las Cuatro Estaciones',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAAoEGu+TAcUcrCj0BN7+oaE1RPOsI',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3UOgmWYfIOXZa2iSTa2quP/tracks',
#     'total': 15},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3UOgmWYfIOXZa2iSTa2quP'},
#   {'collaborative': False,
#    'description': 'Where nature and white noise meet.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWUKPeBypcpcP'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUKPeBypcpcP',
#    'id': '37i9dQZF1DWUKPeBypcpcP',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000002a2d7e4fcdacf7608e5d8611b',
#      'width': None}],
#    'name': 'Nature Noise',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': '#ffffff',
#    'public': True,
#    'snapshot_id': 'ZsdAwwAAAABRS9mXgl/2BP475pgjGPHT',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWUKPeBypcpcP/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWUKPeBypcpcP'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0EuZaZXcWeiWaiUqEEdpSl'},
#    'href': 'https://api.spotify.com/v1/playlists/0EuZaZXcWeiWaiUqEEdpSl',
#    'id': '0EuZaZXcWeiWaiUqEEdpSl',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02524ebe87dc8e2845d91eb21d',
#      'width': None}],
#    'name': 'Radio Musica Clasica – Musica Clasica - Música Clásica de Relajacion, Debussy Claro de Luna, Para Elisa Beethoven y Lo Mejor de la Musica Clasica Musica de Relax',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAA/ApC7pAZ+k/hZQDbRfeWMq2yqsy',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0EuZaZXcWeiWaiUqEEdpSl/tracks',
#     'total': 37},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0EuZaZXcWeiWaiUqEEdpSl'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0O6sLHJYDoP8cNAy0yZexH'},
#    'href': 'https://api.spotify.com/v1/playlists/0O6sLHJYDoP8cNAy0yZexH',
#    'id': '0O6sLHJYDoP8cNAy0yZexH',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e02254deb29b1e07b974e38c182ab67616d00001e022f8dcad0157f0e597b0faff3ab67616d00001e029ded3a35d4dd4d99d0133c89ab67616d00001e02cc12db91c5730797a6059d88',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e02254deb29b1e07b974e38c182ab67616d00001e022f8dcad0157f0e597b0faff3ab67616d00001e029ded3a35d4dd4d99d0133c89ab67616d00001e02cc12db91c5730797a6059d88',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e02254deb29b1e07b974e38c182ab67616d00001e022f8dcad0157f0e597b0faff3ab67616d00001e029ded3a35d4dd4d99d0133c89ab67616d00001e02cc12db91c5730797a6059d88',
#      'width': 60}],
#    'name': 'Mi Música',
#    'owner': {'display_name': 'sarahenares',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/sarahenares'},
#     'href': 'https://api.spotify.com/v1/users/sarahenares',
#     'id': 'sarahenares',
#     'type': 'user',
#     'uri': 'spotify:user:sarahenares'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAABAhRZ3Ze2Y0F4B1IhnEWCXNCZkv/m',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/0O6sLHJYDoP8cNAy0yZexH/tracks',
#     'total': 90},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:0O6sLHJYDoP8cNAy0yZexH'}]}

# %%
playlists = sp.user_playlists('krohell')

for playlist in playlists['items']:
  print(f"{playlist['name']} : {playlist['description']}")
# Out:
# Abrir :
# Chill :
# Goloson :
# Belladonna :
# Belladonna :
# Bum bum gustoso :
# Antequera :
# TECHNO 2024 : The best Techno tracks of 2024!
# Favoritas de la radio :
# Marta infante – Contate Contarini :
# Jacques Offenbach – Offenbach: Vie Parisienne (La) (Excerpts) :
# Marc Minkowski – Offenbach: Orphée aux enfers :
# Hot Ride (Original Mix) :
# One More Time (short radio edit) :
# Three Piece Suit :
# Jazz :
# COTTON!!!!! :
# trankiletes!! :
# House of Jealous Lovers [Cosmos Vs The Rapture] :
# heavy...... :
# VITALIC :
# Riverside - Original Mix :
# OPERA :
# RIVER :
# BEETHOVEN: Piano Sonatas :
# Manuel de FALLA – Falla: Complete Solo Piano Music :
# ALBENIZ: Iberia/Suites españolas :
# Opera 2009 :
# Opera 2010 :
# Various Artists – Great Soprano Arias :
# Tosca (PUCCINI) :
# Boheme (PUCCINI) :
# Turandot (PUCCINI) :
# Madama butterfly (PUCCINI) :
# Requiem (MOZART) :
# Mefistofele (BOITO) :
# La Traviata (VERDI) :
# Nabucco (VERDI) :
# Rigoletto (VERDI) :
# Aida (VERDI) :
# Un ballo in maschera (VERDI) :
# Norma (BELLINI) :
# Il barbiere di Siviglia (ROSSINI) :
# Lakmé (DELIBES) :
# Faust (GOUNOD) :
# King Arthur (PURCELL) :
# Carmina Burana (ORFF) :
# Sonrisas y Lágrimas (The Sound of Music) :
# CHICAGO :
# Moulin Rouge :

# %%
#mas info detalla de las playlists:
playlist = sp.playlist('37i9dQZF1DXcBWIGoYBM5M')
playlist
# Out:
# {'collaborative': False,
#  'description': 'The hottest 50. Cover: Sabrina Carpenter',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#  'followers': {'href': None, 'total': 34883492},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M?additional_types=track',
#  'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000002fe765096aa35d7363f2e9056',
#    'width': None}],
#  'name': 'Today’s Top Hits',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#FFFFFF',
#  'public': True,
#  'snapshot_id': 'ZtFDwAAAAAB6x19Jcq/beNHWCbJcwfz6',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2024-08-23T04:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'album',
#       'href': 'https://api.spotify.com/v1/albums/4B4Elma4nNDUyl6D5PvQkj',
#       'id': '4B4Elma4nNDUyl6D5PvQkj',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2735e1ec3f6b114e4e4924f006f',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e025e1ec3f6b114e4e4924f006f',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d000048515e1ec3f6b114e4e4924f006f',
#         'width': 64,
#         'height': 64}],
#       'name': "Short n' Sweet",
#       'release_date': '2024-08-23',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:4B4Elma4nNDUyl6D5PvQkj',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#         'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#         'id': '74KM79TiuVKeVCqs8QtB0B',
#         'name': 'Sabrina Carpenter',
#         'type': 'artist',
#         'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4B4Elma4nNDUyl6D5PvQkj'},
#       'total_tracks': 12},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#        'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#        'id': '74KM79TiuVKeVCqs8QtB0B',
#        'name': 'Sabrina Carpenter',
#        'type': 'artist',
#        'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 157279,
#      'external_ids': {'isrc': 'USUM72404100'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1d7Ptw3qYcfpdLNL5REhtJ'},
#      'href': 'https://api.spotify.com/v1/tracks/1d7Ptw3qYcfpdLNL5REhtJ',
#      'id': '1d7Ptw3qYcfpdLNL5REhtJ',
#      'name': 'Taste',
#      'popularity': 80,
#      'uri': 'spotify:track:1d7Ptw3qYcfpdLNL5REhtJ',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-08-16T04:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#       'id': '10FLjwfpbxLmW8c25Xyc2N',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#         'width': 64,
#         'height': 64}],
#       'name': 'Die With A Smile',
#       'release_date': '2024-08-16',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#         'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#         'id': '1HY2Jd0NmPuamShAr6KMms',
#         'name': 'Lady Gaga',
#         'type': 'artist',
#         'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#         'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#         'id': '0du5cEVh5yTK9QJze8zA0C',
#         'name': 'Bruno Mars',
#         'type': 'artist',
#         'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 251667,
#      'external_ids': {'isrc': 'USUM72409273'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#      'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#      'id': '2plbrEY59IikOBgBGLjaoe',
#      'name': 'Die With A Smile',
#      'popularity': 95,
#      'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-05-31T04:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'album',
#       'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#       'id': '7aJuG4TFXa2hmE4z1yxc3n',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#         'width': 64,
#         'height': 64}],
#       'name': 'HIT ME HARD AND SOFT',
#       'release_date': '2024-05-17',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#         'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#         'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#         'name': 'Billie Eilish',
#         'type': 'artist',
#         'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#       'total_tracks': 10},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'disc_number': 1,
#      'track_number': 4,
#      'duration_ms': 210373,
#      'external_ids': {'isrc': 'USUM72401994'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'},
#      'href': 'https://api.spotify.com/v1/tracks/6dOtVTDdiauQNBQEDOtlAB',
#      'id': '6dOtVTDdiauQNBQEDOtlAB',
#      'name': 'BIRDS OF A FEATHER',
#      'popularity': 100,
#      'uri': 'spotify:track:6dOtVTDdiauQNBQEDOtlAB',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-04-19T04:01:02Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/1WAjjRMfZjEXtB0lQrAw6Q',
#       'id': '1WAjjRMfZjEXtB0lQrAw6Q',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27391b4bc7c88d91a42e0f3a8b7',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e0291b4bc7c88d91a42e0f3a8b7',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d0000485191b4bc7c88d91a42e0f3a8b7',
#         'width': 64,
#         'height': 64}],
#       'name': 'Good Luck, Babe!',
#       'release_date': '2024-04-05',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:1WAjjRMfZjEXtB0lQrAw6Q',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#         'href': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN',
#         'id': '7GlBOeep6PqTfFi59PTUUN',
#         'name': 'Chappell Roan',
#         'type': 'artist',
#         'uri': 'spotify:artist:7GlBOeep6PqTfFi59PTUUN'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#        'href': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN',
#        'id': '7GlBOeep6PqTfFi59PTUUN',
#        'name': 'Chappell Roan',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GlBOeep6PqTfFi59PTUUN'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 218423,
#      'external_ids': {'isrc': 'USUG12401967'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0WbMK4wrZ1wFSty9F7FCgu'},
#      'href': 'https://api.spotify.com/v1/tracks/0WbMK4wrZ1wFSty9F7FCgu',
#      'id': '0WbMK4wrZ1wFSty9F7FCgu',
#      'name': 'Good Luck, Babe!',
#      'popularity': 97,
#      'uri': 'spotify:track:0WbMK4wrZ1wFSty9F7FCgu',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-03-25T12:43:44Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AU', 'CA', 'PR', 'US'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AU', 'CA', 'PR', 'US'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/1KZC0cX0qq6hodR9YVgh9F',
#       'id': '1KZC0cX0qq6hodR9YVgh9F',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273a5aab55aa65e5f6bd19564a2',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02a5aab55aa65e5f6bd19564a2',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851a5aab55aa65e5f6bd19564a2',
#         'width': 64,
#         'height': 64}],
#       'name': 'Unheard',
#       'release_date': '2024-03-22',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:1KZC0cX0qq6hodR9YVgh9F',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#         'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#         'id': '2FXC3k01G6Gw61bmprjgqS',
#         'name': 'Hozier',
#         'type': 'artist',
#         'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1KZC0cX0qq6hodR9YVgh9F'},
#       'total_tracks': 4},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#        'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#        'id': '2FXC3k01G6Gw61bmprjgqS',
#        'name': 'Hozier',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 251424,
#      'external_ids': {'isrc': 'USSM12401865'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4IadxL6BUymXlh8RCJJu7T'},
#      'href': 'https://api.spotify.com/v1/tracks/4IadxL6BUymXlh8RCJJu7T',
#      'id': '4IadxL6BUymXlh8RCJJu7T',
#      'name': 'Too Sweet',
#      'popularity': 82,
#      'uri': 'spotify:track:4IadxL6BUymXlh8RCJJu7T',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-04-12T04:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': True,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/5quMTd5zeI9yW5UDua8wS4',
#       'id': '5quMTd5zeI9yW5UDua8wS4',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273659cd4673230913b3918e0d5',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02659cd4673230913b3918e0d5',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851659cd4673230913b3918e0d5',
#         'width': 64,
#         'height': 64}],
#       'name': 'Espresso',
#       'release_date': '2024-04-12',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:5quMTd5zeI9yW5UDua8wS4',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#         'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#         'id': '74KM79TiuVKeVCqs8QtB0B',
#         'name': 'Sabrina Carpenter',
#         'type': 'artist',
#         'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#        'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#        'id': '74KM79TiuVKeVCqs8QtB0B',
#        'name': 'Sabrina Carpenter',
#        'type': 'artist',
#        'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 175459,
#      'external_ids': {'isrc': 'USUM72403305'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75'},
#      'href': 'https://api.spotify.com/v1/tracks/2qSkIjg1o9h3YT9RAgYN75',
#      'id': '2qSkIjg1o9h3YT9RAgYN75',
#      'name': 'Espresso',
#      'popularity': 98,
#      'uri': 'spotify:track:2qSkIjg1o9h3YT9RAgYN75',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-08-07T00:45:42Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': 'https://p.scdn.co/mp3-preview/0db1b087630204b761037f90fd5de0c244a5d730?cid=0fa761327b7a4787a964cea122c160f4',
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PL',
#       'PT',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BI',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'MR',
#       'RW',
#       'TG',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PL',
#        'PT',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BI',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'MR',
#        'RW',
#        'TG',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/3ThlxfLSy4bfKzxWqmC7VN',
#       'id': '3ThlxfLSy4bfKzxWqmC7VN',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2738b8d8be49f9c4a44b0574144',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e028b8d8be49f9c4a44b0574144',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d000048518b8d8be49f9c4a44b0574144',
#         'width': 64,
#         'height': 64}],
#       'name': 'Guess featuring Billie Eilish',
#       'release_date': '2024-08-01',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:3ThlxfLSy4bfKzxWqmC7VN',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#         'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#         'id': '25uiPmTg16RbhZWAqwLBy5',
#         'name': 'Charli xcx',
#         'type': 'artist',
#         'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#         'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#         'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#         'name': 'Billie Eilish',
#         'type': 'artist',
#         'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3ThlxfLSy4bfKzxWqmC7VN'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#        'href': 'https://api.spotify.com/v1/artists/25uiPmTg16RbhZWAqwLBy5',
#        'id': '25uiPmTg16RbhZWAqwLBy5',
#        'name': 'Charli xcx',
#        'type': 'artist',
#        'uri': 'spotify:artist:25uiPmTg16RbhZWAqwLBy5'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 143330,
#      'external_ids': {'isrc': 'USAT22406808'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3WOhcATHxK2SLNeP5W3v1v'},
#      'href': 'https://api.spotify.com/v1/tracks/3WOhcATHxK2SLNeP5W3v1v',
#      'id': '3WOhcATHxK2SLNeP5W3v1v',
#      'name': 'Guess featuring Billie Eilish',
#      'popularity': 92,
#      'uri': 'spotify:track:3WOhcATHxK2SLNeP5W3v1v',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-05-10T04:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': None,
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
# ...
#      'popularity': 93,
#      'uri': 'spotify:track:0OA00aPt3BV10qeMIs3meW',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-07-19T04:00:00Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': 'https://p.scdn.co/mp3-preview/34bb0d7c097327243188a812827db8ee336ac10a?cid=0fa761327b7a4787a964cea122c160f4',
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'BY',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/2m0euKZUDcoyEXHIS5MFCq',
#       'id': '2m0euKZUDcoyEXHIS5MFCq',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2734ee35e37bc21fe929a4d3605',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e024ee35e37bc21fe929a4d3605',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d000048514ee35e37bc21fe929a4d3605',
#         'width': 64,
#         'height': 64}],
#       'name': 'Alibi (with Pabllo Vittar & Yseult)',
#       'release_date': '2024-06-28',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:2m0euKZUDcoyEXHIS5MFCq',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MraexJKZDrQYzS98kNwie'},
#         'href': 'https://api.spotify.com/v1/artists/5MraexJKZDrQYzS98kNwie',
#         'id': '5MraexJKZDrQYzS98kNwie',
#         'name': 'Sevdaliza',
#         'type': 'artist',
#         'uri': 'spotify:artist:5MraexJKZDrQYzS98kNwie'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tzRZ39aZlNqlUzQlkuhDV'},
#         'href': 'https://api.spotify.com/v1/artists/6tzRZ39aZlNqlUzQlkuhDV',
#         'id': '6tzRZ39aZlNqlUzQlkuhDV',
#         'name': 'Pabllo Vittar',
#         'type': 'artist',
#         'uri': 'spotify:artist:6tzRZ39aZlNqlUzQlkuhDV'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/1QsdzIKkTT5gDFj8GB1cIX'},
#         'href': 'https://api.spotify.com/v1/artists/1QsdzIKkTT5gDFj8GB1cIX',
#         'id': '1QsdzIKkTT5gDFj8GB1cIX',
#         'name': 'Yseult',
#         'type': 'artist',
#         'uri': 'spotify:artist:1QsdzIKkTT5gDFj8GB1cIX'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2m0euKZUDcoyEXHIS5MFCq'},
#       'total_tracks': 1},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5MraexJKZDrQYzS98kNwie'},
#        'href': 'https://api.spotify.com/v1/artists/5MraexJKZDrQYzS98kNwie',
#        'id': '5MraexJKZDrQYzS98kNwie',
#        'name': 'Sevdaliza',
#        'type': 'artist',
#        'uri': 'spotify:artist:5MraexJKZDrQYzS98kNwie'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tzRZ39aZlNqlUzQlkuhDV'},
#        'href': 'https://api.spotify.com/v1/artists/6tzRZ39aZlNqlUzQlkuhDV',
#        'id': '6tzRZ39aZlNqlUzQlkuhDV',
#        'name': 'Pabllo Vittar',
#        'type': 'artist',
#        'uri': 'spotify:artist:6tzRZ39aZlNqlUzQlkuhDV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1QsdzIKkTT5gDFj8GB1cIX'},
#        'href': 'https://api.spotify.com/v1/artists/1QsdzIKkTT5gDFj8GB1cIX',
#        'id': '1QsdzIKkTT5gDFj8GB1cIX',
#        'name': 'Yseult',
#        'type': 'artist',
#        'uri': 'spotify:artist:1QsdzIKkTT5gDFj8GB1cIX'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 161655,
#      'external_ids': {'isrc': 'NL47E2400004'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5496lks6V3fh1mZAB6IAap'},
#      'href': 'https://api.spotify.com/v1/tracks/5496lks6V3fh1mZAB6IAap',
#      'id': '5496lks6V3fh1mZAB6IAap',
#      'name': 'Alibi (with Pabllo Vittar & Yseult)',
#      'popularity': 92,
#      'uri': 'spotify:track:5496lks6V3fh1mZAB6IAap',
#      'is_local': False},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2024-08-07T18:06:30Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#      'href': 'https://api.spotify.com/v1/users/',
#      'id': '',
#      'type': 'user',
#      'uri': 'spotify:user:'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'preview_url': 'https://p.scdn.co/mp3-preview/2ad9f03400a1744633dec4b907a3d5110931f973?cid=0fa761327b7a4787a964cea122c160f4',
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'explicit': False,
#      'type': 'track',
#      'episode': False,
#      'track': True,
#      'album': {'available_markets': ['AR',
#        'AU',
#        'AT',
#        'BE',
#        'BO',
#        'BR',
#        'BG',
#        'CA',
#        'CL',
#        'CO',
#        'CR',
#        'CY',
#        'CZ',
#        'DK',
#        'DO',
#        'DE',
#        'EC',
#        'EE',
#        'SV',
#        'FI',
#        'FR',
#        'GR',
#        'GT',
#        'HN',
#        'HK',
#        'HU',
#        'IS',
#        'IE',
#        'IT',
#        'LV',
#        'LT',
#        'LU',
#        'MY',
#        'MT',
#        'MX',
#        'NL',
#        'NZ',
#        'NI',
#        'NO',
#        'PA',
#        'PY',
#        'PE',
#        'PH',
#        'PL',
#        'PT',
#        'SG',
#        'SK',
#        'ES',
#        'SE',
#        'CH',
#        'TW',
#        'TR',
#        'UY',
#        'US',
#        'GB',
#        'AD',
#        'LI',
#        'MC',
#        'ID',
#        'JP',
#        'TH',
#        'VN',
#        'RO',
#        'IL',
#        'ZA',
#        'SA',
#        'AE',
#        'BH',
#        'QA',
#        'OM',
#        'KW',
#        'EG',
#        'MA',
#        'DZ',
#        'TN',
#        'LB',
#        'JO',
#        'PS',
#        'IN',
#        'KZ',
#        'MD',
#        'UA',
#        'AL',
#        'BA',
#        'HR',
#        'ME',
#        'MK',
#        'RS',
#        'SI',
#        'KR',
#        'BD',
#        'PK',
#        'LK',
#        'GH',
#        'KE',
#        'NG',
#        'TZ',
#        'UG',
#        'AG',
#        'AM',
#        'BS',
#        'BB',
#        'BZ',
#        'BT',
#        'BW',
#        'BF',
#        'CV',
#        'CW',
#        'DM',
#        'FJ',
#        'GM',
#        'GE',
#        'GD',
#        'GW',
#        'GY',
#        'HT',
#        'JM',
#        'KI',
#        'LS',
#        'LR',
#        'MW',
#        'MV',
#        'ML',
#        'MH',
#        'FM',
#        'NA',
#        'NR',
#        'NE',
#        'PW',
#        'PG',
#        'PR',
#        'WS',
#        'SM',
#        'ST',
#        'SN',
#        'SC',
#        'SL',
#        'SB',
#        'KN',
#        'LC',
#        'VC',
#        'SR',
#        'TL',
#        'TO',
#        'TT',
#        'TV',
#        'VU',
#        'AZ',
#        'BN',
#        'BI',
#        'KH',
#        'CM',
#        'TD',
#        'KM',
#        'GQ',
#        'SZ',
#        'GA',
#        'GN',
#        'KG',
#        'LA',
#        'MO',
#        'MR',
#        'MN',
#        'NP',
#        'RW',
#        'TG',
#        'UZ',
#        'ZW',
#        'BJ',
#        'MG',
#        'MU',
#        'MZ',
#        'AO',
#        'CI',
#        'DJ',
#        'ZM',
#        'CD',
#        'CG',
#        'IQ',
#        'LY',
#        'TJ',
#        'VE',
#        'ET',
#        'XK'],
#       'type': 'album',
#       'album_type': 'single',
#       'href': 'https://api.spotify.com/v1/albums/5Zwbll6KYxOjZSuxRjQDEm',
#       'id': '5Zwbll6KYxOjZSuxRjQDEm',
#       'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273f2cd132495d61b0da6a900d2',
#         'width': 640,
#         'height': 640},
#        {'url': 'https://i.scdn.co/image/ab67616d00001e02f2cd132495d61b0da6a900d2',
#         'width': 300,
#         'height': 300},
#        {'url': 'https://i.scdn.co/image/ab67616d00004851f2cd132495d61b0da6a900d2',
#         'width': 64,
#         'height': 64}],
#       'name': 'KEHLANI',
#       'release_date': '2024-06-24',
#       'release_date_precision': 'day',
#       'uri': 'spotify:album:5Zwbll6KYxOjZSuxRjQDEm',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jPHHnU8GUWEF7rwPE9osY'},
#         'href': 'https://api.spotify.com/v1/artists/0jPHHnU8GUWEF7rwPE9osY',
#         'id': '0jPHHnU8GUWEF7rwPE9osY',
#         'name': 'Jordan Adetunji',
#         'type': 'artist',
#         'uri': 'spotify:artist:0jPHHnU8GUWEF7rwPE9osY'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5Zwbll6KYxOjZSuxRjQDEm'},
#       'total_tracks': 3},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jPHHnU8GUWEF7rwPE9osY'},
#        'href': 'https://api.spotify.com/v1/artists/0jPHHnU8GUWEF7rwPE9osY',
#        'id': '0jPHHnU8GUWEF7rwPE9osY',
#        'name': 'Jordan Adetunji',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jPHHnU8GUWEF7rwPE9osY'}],
#      'disc_number': 1,
#      'track_number': 1,
#      'duration_ms': 122360,
#      'external_ids': {'isrc': 'USAT22405690'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2hrycoFU1mZw6YPvMcn8yC'},
#      'href': 'https://api.spotify.com/v1/tracks/2hrycoFU1mZw6YPvMcn8yC',
#      'id': '2hrycoFU1mZw6YPvMcn8yC',
#      'name': 'KEHLANI',
#      'popularity': 89,
#      'uri': 'spotify:track:2hrycoFU1mZw6YPvMcn8yC',
#      'is_local': False},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 50},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:37i9dQZF1DXcBWIGoYBM5M'}

# %%
for playlist in playlists['items']:
    print(playlist['name'])
    print(playlist['id'])
    print(playlist['external_urls']['spotify'])
    print(playlist['tracks']['total'])
# Out:
# Abrir
# 17Zl1pViyl3g6Xb9DtJGy3
# https://open.spotify.com/playlist/17Zl1pViyl3g6Xb9DtJGy3
# 3
# Chill
# 62vyosUAQNcB6NZOQLFABM
# https://open.spotify.com/playlist/62vyosUAQNcB6NZOQLFABM
# 1
# Goloson
# 4SZFyNtcYLKuyxk10aq9Ft
# https://open.spotify.com/playlist/4SZFyNtcYLKuyxk10aq9Ft
# 1
# Belladonna
# 2wyuSFZeRGxxsL2uw2VOcK
# https://open.spotify.com/playlist/2wyuSFZeRGxxsL2uw2VOcK
# 26
# Belladonna
# 1veoDsyXRD1SYDnBajJ76t
# https://open.spotify.com/playlist/1veoDsyXRD1SYDnBajJ76t
# 1
# Bum bum gustoso
# 3hNW4EE25hx4NgVqxMOIwX
# https://open.spotify.com/playlist/3hNW4EE25hx4NgVqxMOIwX
# 2
# Antequera
# 0t5wUOq74Bt7F7i73NpT8K
# https://open.spotify.com/playlist/0t5wUOq74Bt7F7i73NpT8K
# 3
# TECHNO 2024
# 5qUiLFZRY0CdQJJNnvDMtY
# https://open.spotify.com/playlist/5qUiLFZRY0CdQJJNnvDMtY
# 119
# Favoritas de la radio
# 01BtDOtqAmVFnnUEudMl1f
# https://open.spotify.com/playlist/01BtDOtqAmVFnnUEudMl1f
# 3
# Marta infante – Contate Contarini
# 0TQPtkGqLEJ1Z3Km1xbqzs
# https://open.spotify.com/playlist/0TQPtkGqLEJ1Z3Km1xbqzs
# 9
# Jacques Offenbach – Offenbach: Vie Parisienne (La) (Excerpts)
# 5is0XflPGBlWDiIBpifh8D
# https://open.spotify.com/playlist/5is0XflPGBlWDiIBpifh8D
# 24
# Marc Minkowski – Offenbach: Orphée aux enfers
# 5josBCtMrIkQhJwkjGqyjO
# https://open.spotify.com/playlist/5josBCtMrIkQhJwkjGqyjO
# 53
# Hot Ride (Original Mix)
# 37Pi4pBgTFN0xGHZ4pBdfj
# https://open.spotify.com/playlist/37Pi4pBgTFN0xGHZ4pBdfj
# 271
# One More Time (short radio edit)
# 0d81SBLbFbDg9Q2Amn1rrh
# https://open.spotify.com/playlist/0d81SBLbFbDg9Q2Amn1rrh
# 81
# Three Piece Suit
# 6czaKnmyUkBksWAgdLDQtw
# https://open.spotify.com/playlist/6czaKnmyUkBksWAgdLDQtw
# 3
# Jazz
# 2JjPesKQU4qhNLfBJIz51r
# https://open.spotify.com/playlist/2JjPesKQU4qhNLfBJIz51r
# 1
# COTTON!!!!!
# 0KkLTKYmPnkfSur298R5a3
# https://open.spotify.com/playlist/0KkLTKYmPnkfSur298R5a3
# 31
# trankiletes!!
# 3haqzvQtJ18iKn8hPDkFoc
# https://open.spotify.com/playlist/3haqzvQtJ18iKn8hPDkFoc
# 6
# House of Jealous Lovers [Cosmos Vs The Rapture]
# 5kDdeRZQlGc4UggLCPYw6O
# https://open.spotify.com/playlist/5kDdeRZQlGc4UggLCPYw6O
# 2
# heavy......
# 4w7889V6iPAK7FFzp2JLh5
# https://open.spotify.com/playlist/4w7889V6iPAK7FFzp2JLh5
# 1
# VITALIC
# 7dlOy8Tk4LGJ6X9mHh8ylL
# https://open.spotify.com/playlist/7dlOy8Tk4LGJ6X9mHh8ylL
# 65
# Riverside - Original Mix
# 5b0PzqjYQ69jbsJBKHoHdZ
# https://open.spotify.com/playlist/5b0PzqjYQ69jbsJBKHoHdZ
# 1
# OPERA
# 7JrH9rz04LMkmV5rkHxnlj
# https://open.spotify.com/playlist/7JrH9rz04LMkmV5rkHxnlj
# 3
# RIVER
# 0eGWRwbDR8uBqEmWGcU8ON
# https://open.spotify.com/playlist/0eGWRwbDR8uBqEmWGcU8ON
# 9
# BEETHOVEN: Piano Sonatas
# 6RNeqSaSuVZgMhoGI6Ih6D
# https://open.spotify.com/playlist/6RNeqSaSuVZgMhoGI6Ih6D
# 35
# Manuel de FALLA – Falla: Complete Solo Piano Music
# 61PH7sohsImHXTaUspqwSR
# https://open.spotify.com/playlist/61PH7sohsImHXTaUspqwSR
# 16
# ALBENIZ: Iberia/Suites españolas
# 6LHjaNS2jZEZyMGeMVP4t9
# https://open.spotify.com/playlist/6LHjaNS2jZEZyMGeMVP4t9
# 22
# Opera 2009
# 5wTRxwooYUHLGG48pyou2F
# https://open.spotify.com/playlist/5wTRxwooYUHLGG48pyou2F
# 40
# Opera 2010
# 2IVHzKZso0mhl0gN7A8JKe
# https://open.spotify.com/playlist/2IVHzKZso0mhl0gN7A8JKe
# 40
# Various Artists – Great Soprano Arias
# 1nAdNmwWjDhdIJheITThaK
# https://open.spotify.com/playlist/1nAdNmwWjDhdIJheITThaK
# 17
# Tosca (PUCCINI)
# 2TYdhfx1VnFO9GMYGhPjAu
# https://open.spotify.com/playlist/2TYdhfx1VnFO9GMYGhPjAu
# 59
# Boheme (PUCCINI)
# 7rID2OZsYpLMd3EdVTK6PQ
# https://open.spotify.com/playlist/7rID2OZsYpLMd3EdVTK6PQ
# 32
# Turandot (PUCCINI)
# 0so8JmRgznxMaxnL1l8VuX
# https://open.spotify.com/playlist/0so8JmRgznxMaxnL1l8VuX
# 44
# Madama butterfly (PUCCINI)
# 4nR9eRCMiJagPgoVQ74hog
# https://open.spotify.com/playlist/4nR9eRCMiJagPgoVQ74hog
# 34
# Requiem (MOZART)
# 1Vp0PcEnjmHGtXMSyekoF5
# https://open.spotify.com/playlist/1Vp0PcEnjmHGtXMSyekoF5
# 14
# Mefistofele (BOITO)
# 0lgQKy3YxbqCqycChdoKIo
# https://open.spotify.com/playlist/0lgQKy3YxbqCqycChdoKIo
# 36
# La Traviata (VERDI)
# 0r0Fyr18dtSZXN351vFM4I
# https://open.spotify.com/playlist/0r0Fyr18dtSZXN351vFM4I
# 45
# Nabucco (VERDI)
# 3tp5ZO6gZE2rpA5uAt4iXC
# https://open.spotify.com/playlist/3tp5ZO6gZE2rpA5uAt4iXC
# 42
# Rigoletto (VERDI)
# 17vHPr3AOvmVC0RUOBw3oE
# https://open.spotify.com/playlist/17vHPr3AOvmVC0RUOBw3oE
# 36
# Aida (VERDI)
# 70ElVMi6PqBMb0t3JIf4JM
# https://open.spotify.com/playlist/70ElVMi6PqBMb0t3JIf4JM
# 55
# Un ballo in maschera (VERDI)
# 2X0jBVHwRV4Aa1BKPT5ol5
# https://open.spotify.com/playlist/2X0jBVHwRV4Aa1BKPT5ol5
# 92
# Norma (BELLINI)
# 1kczD3dDRabgRLxxNtqhJa
# https://open.spotify.com/playlist/1kczD3dDRabgRLxxNtqhJa
# 44
# Il barbiere di Siviglia (ROSSINI)
# 65z06b5mg5TBkZvMaasO1p
# https://open.spotify.com/playlist/65z06b5mg5TBkZvMaasO1p
# 80
# Lakmé (DELIBES)
# 1ngyikLBfDcWiIm78QevMY
# https://open.spotify.com/playlist/1ngyikLBfDcWiIm78QevMY
# 58
# Faust (GOUNOD)
# 5N02pn0etk76TBc6K21CgT
# https://open.spotify.com/playlist/5N02pn0etk76TBc6K21CgT
# 64
# King Arthur (PURCELL)
# 4RID7zbfgATcqjKRFgLMwj
# https://open.spotify.com/playlist/4RID7zbfgATcqjKRFgLMwj
# 39
# Carmina Burana (ORFF)
# 0L24WNPQnSuynJVvqIqnyk
# https://open.spotify.com/playlist/0L24WNPQnSuynJVvqIqnyk
# 25
# Sonrisas y Lágrimas (The Sound of Music)
# 3csNlFjnJEgEyNeTysvQ85
# https://open.spotify.com/playlist/3csNlFjnJEgEyNeTysvQ85
# 16
# CHICAGO
# 0NxKTv3llEMsbZmiIqCLnj
# https://open.spotify.com/playlist/0NxKTv3llEMsbZmiIqCLnj
# 22
# Moulin Rouge
# 1WRt7OgCI3nuS2iFeT7lZm
# https://open.spotify.com/playlist/1WRt7OgCI3nuS2iFeT7lZm
# 16

# %%
#Buscamos una canción
results = sp.search(q='Se me enamora el alma', limit=20)
results['tracks']['items'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6605314124b0> in <cell line: 2>()
#       1 #Buscamos una canción
# ----> 2 results = sp.search(q='Se me enamora el alma', limit=20)
#       3 results['tracks']['items'][0]
#
# NameError: name 'sp' is not defined

# %%
#Acceder a track_href para ver la info de la canción
results['tracks']['items'][0]['href']

#Vamos a ver la info de la canción
sp.track('6y0igZArWVi6Iz0rj35c1Y')
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#     'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#     'id': '6nxWCVXbOlEVRexSbLsTer',
#     'name': 'Flume',
#     'type': 'artist',
#     'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'}],
#   'available_markets': [],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5eTAmV8stngDTcO4veqyVK'},
#   'href': 'https://api.spotify.com/v1/albums/5eTAmV8stngDTcO4veqyVK',
#   'id': '5eTAmV8stngDTcO4veqyVK',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273f221ae4798e902bf102e1bd2',
#     'width': 640,
#     'height': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02f221ae4798e902bf102e1bd2',
#     'width': 300,
#     'height': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851f221ae4798e902bf102e1bd2',
#     'width': 64,
#     'height': 64}],
#   'name': 'Never Be Like You (feat. Kai)',
#   'release_date': '2016-01-16',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5eTAmV8stngDTcO4veqyVK'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nxWCVXbOlEVRexSbLsTer'},
#    'href': 'https://api.spotify.com/v1/artists/6nxWCVXbOlEVRexSbLsTer',
#    'id': '6nxWCVXbOlEVRexSbLsTer',
#    'name': 'Flume',
#    'type': 'artist',
#    'uri': 'spotify:artist:6nxWCVXbOlEVRexSbLsTer'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6xHUXzrfhFgnIv86EBR3Ml'},
#    'href': 'https://api.spotify.com/v1/artists/6xHUXzrfhFgnIv86EBR3Ml',
#    'id': '6xHUXzrfhFgnIv86EBR3Ml',
#    'name': 'kai',
#    'type': 'artist',
#    'uri': 'spotify:artist:6xHUXzrfhFgnIv86EBR3Ml'}],
#  'available_markets': [],
#  'disc_number': 1,
#  'duration_ms': 234909,
#  'explicit': True,
#  'external_ids': {'isrc': 'AUFF01500784'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6y0igZArWVi6Iz0rj35c1Y'},
#  'href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'is_local': False,
#  'name': 'Never Be Like You (feat. Kai)',
#  'popularity': 0,
#  'preview_url': 'https://p.scdn.co/mp3-preview/903690bfff934f4c90a2accac3cd741fec70c637?cid=0fa761327b7a4787a964cea122c160f4',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y'}
